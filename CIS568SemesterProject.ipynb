# %%
import pandas as pd

# %%
df = pd.read_csv('soilRestoration.csv')
df.head()
# Out:
#    OTU_ID  T2CKQ.1  T2CKQ.2  T2CKQ.3  T2CQ.1  T2CQ.2  T2CQ.3  T2YCQ.1  \
# 0       1        1        0        0       1       1       1        4
# 1       2      999     1002     1069     642     535     602      623
# 2       3       73       62       85      34      37      29       74
# 3       4        0        0        0       0       0       0        0
# 4       5       42       29       39      95      86      81       48
#
#    T2YCQ.2  T2YCQ.3  T2ZJQ.1  T2ZJQ.2  T2ZJQ.3  \
# 0        4       12        3        3        0
# 1      594      610      485      448      426
# 2       65       74       77       85       78
# 3        0        0        0        2        1
# 4       47       47       22       28       23
#
#                                             taxonomy
# 0  k__Bacteria; p__Proteobacteria; c__Gammaproteo...
# 1  k__Bacteria; p__Proteobacteria; c__Alphaproteo...
# 2  k__Bacteria; p__Proteobacteria; c__Gammaproteo...
# ...

# %%
df.rename(columns={'OTU_ID': 'ID', 'T2CKQ.1': 'BareSoilQ1', 'T2CKQ.2': 'BareSoilQ2', 'T2CKQ.3': 'BareSoilQ3', 'T2CQ.1': 'GrasslandsQ1', 'T2CQ.2': 'GrasslandsQ2', 'T2CQ.3': 'GrasslandsQ3', 'T2YCQ.1': 'PoplarQ1', 'T2YCQ.2': 'PoplarQ2', 'T2YCQ.3': 'PoplarQ3', 'T2ZJQ.1': 'MixForestQ1', 'T2ZJQ.2': 'MixForestQ2', 'T2ZJQ.3': 'MixForestQ3'}, inplace=True)

# %%
df
# Out:
#           ID  BareSoilQ1  BareSoilQ2  BareSoilQ3  GrasslandsQ1  GrasslandsQ2  \
# 0          1           1           0           0             1             1
# 1          2         999        1002        1069           642           535
# 2          3          73          62          85            34            37
# 3          4           0           0           0             0             0
# 4          5          42          29          39            95            86
# ...      ...         ...         ...         ...           ...           ...
# 40319  40320           0           0           0             0             0
# 40320  40321           0           0           0             0             0
# 40321  40322           0           0           0             0             0
# 40322  40323           0           0           0             0             0
# 40323  40324           0           0           0             0             0
#
# ...

# %% [markdown]
# # Scatterplots

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
#make all of the different columns into numpy arrays for plotting
ID = df['ID'].to_numpy()

#bs is base soil
BSQ1Arr = df['BareSoilQ1'].to_numpy()
BSQ2Arr = df['BareSoilQ2'].to_numpy()
BSQ3Arr = df['BareSoilQ3'].to_numpy()

#gl is grasslands
GLQ1Arr = df['GrasslandsQ1'].to_numpy()
GLQ2Arr = df['GrasslandsQ2'].to_numpy()
GLQ3Arr = df['GrasslandsQ3'].to_numpy()

#p is poplar
PQ1Arr = df['PoplarQ1'].to_numpy()
PQ2Arr = df['PoplarQ2'].to_numpy()
PQ3Arr = df['PoplarQ3'].to_numpy()

#mf is mixed forest
MFQ1Arr = df['MixForestQ1'].to_numpy()
MFQ2Arr = df['MixForestQ2'].to_numpy()
MFQ3Arr = df['MixForestQ3'].to_numpy()

# %%
#adding theme color for background
plt.figure(facecolor = "#0AB68B")

#plot the bacteria composition count against composition ID
plt.scatter(BSQ1Arr, ID, color = "#028174")

#add title and x axis label
plt.title("Bare Soil Quarter 1 Composition Scatterplot", fontweight = 'bold')
plt.xlabel("Count", fontweight = 'bold')

#use gca to define axes to color inside axes
ax = plt.gca()
ax.set_facecolor("#FFF0B6")

#label y axis
plt.ylabel("Bacteria Composition ID", fontweight = 'bold')

#save the figure
plt.show()
plt.savefig("scatterplotB1.png")

# %%
#adding theme color for background
plt.figure(facecolor = "#0AB68B")

#plot the bacteria composition count against composition ID
plt.scatter(BSQ2Arr, ID, color = "#028174")

#add title and x axis label
plt.title("Bare Soil Quarter 2 Composition Scatterplot", fontweight = 'bold')
plt.xlabel("Count", fontweight = 'bold')

#use gca to define axes to color inside axes
ax = plt.gca()
ax.set_facecolor("#FFF0B6")

#label y axis
plt.ylabel("Bacteria Composition ID", fontweight = 'bold')

#save the figure
plt.show()
plt.savefig("scatterplotB2.png")

# %%
#adding theme color for background
plt.figure(facecolor = "#0AB68B")

#plot the bacteria composition count against composition ID
plt.scatter(BSQ3Arr, ID, color = "#028174")

#add title and x axis label
plt.title("Bare Soil Quarter 3 Composition Scatterplot", fontweight = 'bold')
plt.xlabel("Count", fontweight = 'bold')

#use gca to define axes to color inside axes
ax = plt.gca()
ax.set_facecolor("#FFF0B6")

#label y axis
plt.ylabel("Bacteria Composition ID", fontweight = 'bold')

#save the figure
plt.show()
plt.savefig("scatterplotB3.png")

# %%
#adding theme color for background
plt.figure(facecolor = "#0AB68B")

#plot the bacteria composition count against composition ID
plt.scatter(GLQ1Arr, ID, color = "#028174")

#add title and x axis label
plt.title("Grasslands Quarter 1 Composition Scatterplot", fontweight = 'bold')
plt.xlabel("Count", fontweight = 'bold')

#use gca to define axes to color inside axes
ax = plt.gca()
ax.set_facecolor("#FFF0B6")

#label y axis
plt.ylabel("Bacteria Composition ID", fontweight = 'bold')

#save the figure
plt.show()
plt.savefig("scatterplotG1.png")

# %%
#adding theme color for background
plt.figure(facecolor = "#0AB68B")

#plot the bacteria composition count against composition ID
plt.scatter(GLQ2Arr, ID, color = "#028174")

#add title and x axis label
plt.title("Grasslands Quarter 2 Composition Scatterplot", fontweight = 'bold')
plt.xlabel("Count", fontweight = 'bold')

#use gca to define axes to color inside axes
ax = plt.gca()
ax.set_facecolor("#FFF0B6")

#label y axis
plt.ylabel("Bacteria Composition ID", fontweight = 'bold')

#save the figure
plt.show()
plt.savefig("scatterplotG2.png")

# %%
#adding theme color for background
plt.figure(facecolor = "#0AB68B")

#plot the bacteria composition count against composition ID
plt.scatter(GLQ3Arr, ID, color = "#028174")

#add title and x axis label
plt.title("Grasslands Quarter 3 Composition Scatterplot", fontweight = 'bold')
plt.xlabel("Count", fontweight = 'bold')

#use gca to define axes to color inside axes
ax = plt.gca()
ax.set_facecolor("#FFF0B6")

#label y axis
plt.ylabel("Bacteria Composition ID", fontweight = 'bold')

#save the figure
plt.show()
plt.savefig("scatterplotG3.png")

# %%
#adding theme color for background
plt.figure(facecolor = "#0AB68B")

#plot the bacteria composition count against composition ID
plt.scatter(PQ1Arr, ID, color = "#028174")

#add title and x axis label
plt.title("Poplar Quarter 1 Composition Scatterplot", fontweight = 'bold')
plt.xlabel("Count", fontweight = 'bold')

#use gca to define axes to color inside axes
ax = plt.gca()
ax.set_facecolor("#FFF0B6")

#label y axis
plt.ylabel("Bacteria Composition ID", fontweight = 'bold')

#save the figure
plt.show()
plt.savefig("scatterplotG1.png")

# %%
#adding theme color for background
plt.figure(facecolor = "#0AB68B")

#plot the bacteria composition count against composition ID
plt.scatter(PQ2Arr, ID, color = "#028174")

#add title and x axis label
plt.title("Poplar Plantation Quarter 2 Composition Scatterplot", fontweight = 'bold')
plt.xlabel("Count", fontweight = 'bold')

#use gca to define axes to color inside axes
ax = plt.gca()
ax.set_facecolor("#FFF0B6")

#label y axis
plt.ylabel("Bacteria Composition ID", fontweight = 'bold')

#save the figure
plt.show()
plt.savefig("scatterplotP2.png")

# %%
#adding theme color for background
plt.figure(facecolor = "#0AB68B")

#plot the bacteria composition count against composition ID
plt.scatter(PQ3Arr, ID, color = "#028174")

#add title and x axis label
plt.title("Poplar Plantation Quarter 3 Composition Scatterplot", fontweight = 'bold')
plt.xlabel("Count", fontweight = 'bold')

#use gca to define axes to color inside axes
ax = plt.gca()
ax.set_facecolor("#FFF0B6")

#label y axis
plt.ylabel("Bacteria Composition ID", fontweight = 'bold')

#save the figure
plt.show()
plt.savefig("scatterplotP3.png")

# %%
#adding theme color for background
plt.figure(facecolor = "#0AB68B")

#plot the bacteria composition count against composition ID
plt.scatter(MFQ1Arr, ID, color = "#028174")

#add title and x axis label
plt.title("Mixed Forest Quarter 1 Composition Scatterplot", fontweight = 'bold')
plt.xlabel("Count", fontweight = 'bold')

#use gca to define axes to color inside axes
ax = plt.gca()
ax.set_facecolor("#FFF0B6")

#label y axis
plt.ylabel("Bacteria Composition ID", fontweight = 'bold')

#save the figure
plt.show()
plt.savefig("scatterplotM1.png")

# %%
#adding theme color for background
plt.figure(facecolor = "#0AB68B")

#plot the bacteria composition count against composition ID
plt.scatter(MFQ2Arr, ID, color = "#028174")

#add title and x axis label
plt.title("Mixed Forest Quarter 2 Composition Scatterplot", fontweight = 'bold')
plt.xlabel("Count", fontweight = 'bold')

#use gca to define axes to color inside axes
ax = plt.gca()
ax.set_facecolor("#FFF0B6")

#label y axis
plt.ylabel("Bacteria Composition ID", fontweight = 'bold')

#save the figure
plt.show()
plt.savefig("scatterplotM2.png")

# %%
#adding theme color for background
plt.figure(facecolor = "#0AB68B")

#plot the bacteria composition count against composition ID
plt.scatter(MFQ3Arr, ID, color = "#028174")

#add title and x axis label
plt.title("Mixed Forest Quarter 3 Composition Scatterplot", fontweight = 'bold')
plt.xlabel("Count", fontweight = 'bold')

#use gca to define axes to color inside axes
ax = plt.gca()
ax.set_facecolor("#FFF0B6")

#label y axis
plt.ylabel("Bacteria Composition ID", fontweight = 'bold')

#save the figure
plt.show()
plt.savefig("scatterplotM3.png")

# %% [markdown]
# # Bar Charts

# %%
#drop every row but the top three because the three bacteria compositions are being plotted
dfBar = df.drop(df.index[3:])
dfBar
# Out:
#    ID  BareSoilQ1  BareSoilQ2  BareSoilQ3  GrasslandsQ1  GrasslandsQ2  \
# 0   1           1           0           0             1             1
# 1   2         999        1002        1069           642           535
# 2   3          73          62          85            34            37
#
#    GrasslandsQ3  PoplarQ1  PoplarQ2  PoplarQ3  MixForestQ1  MixForestQ2  \
# 0             1         4         4        12            3            3
# 1           602       623       594       610          485          448
# 2            29        74        65        74           77           85
#
#    MixForestQ3                                           taxonomy
# 0            0  k__Bacteria; p__Proteobacteria; c__Gammaproteo...
# 1          426  k__Bacteria; p__Proteobacteria; c__Alphaproteo...
# 2           78  k__Bacteria; p__Proteobacteria; c__Gammaproteo...

# %%
#make all of the different columns into numpy arrays for plotting
bcID = dfBar['ID'].to_numpy()

#bs is base soil
bcBSQ1Arr = dfBar['BareSoilQ1'].to_numpy()
bcBSQ2Arr = dfBar['BareSoilQ2'].to_numpy()
bcBSQ3Arr = dfBar['BareSoilQ3'].to_numpy()

#gl is grasslands
bcGLQ1Arr = dfBar['GrasslandsQ1'].to_numpy()
bcGLQ2Arr = dfBar['GrasslandsQ2'].to_numpy()
bcGLQ3Arr = dfBar['GrasslandsQ3'].to_numpy()

#p is poplar
bcPQ1Arr = dfBar['PoplarQ1'].to_numpy()
bcPQ2Arr = dfBar['PoplarQ2'].to_numpy()
bcPQ3Arr = dfBar['PoplarQ3'].to_numpy()

#mf is mixed forest
bcMFQ1Arr = dfBar['MixForestQ1'].to_numpy()
bcMFQ2Arr = dfBar['MixForestQ2'].to_numpy()
bcMFQ3Arr = dfBar['MixForestQ3'].to_numpy()

# %%
#adding theme color for background
plt.figure(facecolor = "#0AB68B")

#make the bars
width = 0.2
plt.bar(bcID-0.3, bcBSQ1Arr, width, color='#0c0f5c')
plt.bar(bcID-0.1, bcGLQ1Arr, width, color='#5c3d0c')
plt.bar(bcID+0.1, bcPQ1Arr, width, color='#2d0c5c')
plt.bar(bcID+0.3, bcMFQ1Arr, width, color='#5c0c19')

#add the title and x axis labels
plt.title("Quarter 1 Bacteria Compositions", fontweight = 'bold')
plt.xticks(bcID, ['Composition 1', 'Composition 2', 'Composition 3'])
plt.xlabel("Bacteria Compositions", fontweight = 'bold')

#use gca to define axes to color inside axes
ax = plt.gca()
ax.set_facecolor("#FFF0B6")

#set y label
plt.ylabel("Count", fontweight = 'bold')

#create the legend with the soil types
plt.legend(["Bare Soil", "Grasslands", "Poplar Plantation", "Mixed Forest"])

#save plot
plt.show()
plt.savefig("barchartQ1.png")

# %%
#adding theme color for background
plt.figure(facecolor = "#0AB68B")

#make the bars
width = 0.2
plt.bar(bcID-0.3, bcBSQ2Arr, width, color='#0c0f5c')
plt.bar(bcID-0.1, bcGLQ2Arr, width, color='#5c3d0c')
plt.bar(bcID+0.1, bcPQ2Arr, width, color='#2d0c5c')
plt.bar(bcID+0.3, bcMFQ2Arr, width, color='#5c0c19')

#add the title and x axis labels
plt.title("Quarter 2 Bacteria Compositions", fontweight = 'bold')
plt.xticks(bcID, ['Composition 1', 'Composition 2', 'Composition 3'])
plt.xlabel("Bacteria Compositions", fontweight = 'bold')

#use gca to define axes to color inside axes
ax = plt.gca()
ax.set_facecolor("#FFF0B6")

#set y label
plt.ylabel("Count", fontweight = 'bold')

#create the legend with the soil types
plt.legend(["Bare Soil", "Grasslands", "Poplar Plantation", "Mixed Forest"])

#save plot
plt.show()
plt.savefig("barchartQ2.png")

# %%
#adding theme color for background
plt.figure(facecolor = "#0AB68B")

#make the bars
width = 0.2
plt.bar(bcID-0.3, bcBSQ3Arr, width, color='#0c0f5c')
plt.bar(bcID-0.1, bcGLQ3Arr, width, color='#5c3d0c')
plt.bar(bcID+0.1, bcPQ3Arr, width, color='#2d0c5c')
plt.bar(bcID+0.3, bcMFQ3Arr, width, color='#5c0c19')

#add the title and x axis labels
plt.title("Quarter 3 Bacteria Compositions", fontweight = 'bold')
plt.xticks(bcID, ['Composition 1', 'Composition 2', 'Composition 3'])
plt.xlabel("Bacteria Compositions", fontweight = 'bold')

#use gca to define axes to color inside axes
ax = plt.gca()
ax.set_facecolor("#FFF0B6")

#set y label
plt.ylabel("Count", fontweight = 'bold')

#create the legend with the soil types
plt.legend(["Bare Soil", "Grasslands", "Poplar Plantation", "Mixed Forest"])

#save plot
plt.show()
plt.savefig("barchartQ3.png")
